# %%
import numpy as np
import matplotlib.pyplot as plt

history = np.load('./saved/history.npy',allow_pickle='TRUE').item()

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 4))
axs[0].plot(history['loss1'])
axs[1].plot(history['loss2'])

# %%
nX = np.array(history['nX'])
fig, axs = plt.subplots(figsize=(10, 4))
axs.plot(np.exp(nX))

# %%
nX.shape
# Out:
# (50000, 4)
